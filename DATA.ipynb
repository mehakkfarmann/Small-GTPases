# %% [markdown]
# # COLLECTION OF DATA

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.8.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.2.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.4.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.6 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.3 MB/s eta 0:00:00
# Downloading cattrs-25.2.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 6.2 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.2.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %%
import pandas as pd
import time
from chembl_webresource_client.new_client import new_client

# Initialize ChEMBL client
activity = new_client.activity
target = new_client.target

# Step 1: Search for Small GTPase family targets
target_query = target.search("Small GTPase")
targets = pd.DataFrame.from_dict(target_query)

# %%
# Step 2: Filter only human small GTPases
human_gtpases = targets[
    (targets["organism"] == "Homo sapiens") &
    (targets["target_type"] == "SINGLE PROTEIN")
]
human_gtpases = human_gtpases.dropna(subset=["target_chembl_id", "pref_name"])
human_gtpases = human_gtpases.drop_duplicates(subset=["target_chembl_id"])

print(f"✅ Found {len(human_gtpases)} human small GTPase targets")
print(human_gtpases[["pref_name", "target_chembl_id"]])
# Out:
# ✅ Found 69 human small GTPase targets
#                                              pref_name target_chembl_id
# 0                            GTP-binding protein SAR1a    CHEMBL4295960
# 3          Dynamin-like 120 kDa protein, mitochondrial    CHEMBL4105705
# 4    ADP-ribosylation factor GTPase-activating prot...    CHEMBL5465332
# 5                     Transforming protein p21/H-Ras-1       CHEMBL2167
# 6                                          GTPase NRas    CHEMBL2079845
# ..                                                 ...              ...
# 124                                          Caspase-7       CHEMBL3468
# 125                                         Caspase-10       CHEMBL5037
# 127                                         Caspase-14       CHEMBL5991
# 133                             C-C motif chemokine 22    CHEMBL4295649
# 134  Aminoacyl tRNA synthase complex-interacting mu...    CHEMBL4295810
#
# [69 rows x 2 columns]

# %%
bioactivity_list = []

for idx, row in human_gtpases.iterrows():
    target_name = row["pref_name"]
    target_id = row["target_chembl_id"]

    print(f"\nFetching {target_name} ({target_id})...")

    try:
        # Strict filters
        records = activity.filter(
            target_chembl_id=target_id,
            standard_type="IC50",
            standard_units="nM"
        )

        df = pd.DataFrame.from_dict(records)

        if df.empty:
            print(f"⚠️ No IC50 records for {target_name}")
            continue

        # Remove NaNs
        df = df.dropna(subset=["standard_value", "canonical_smiles"])

        # Keep only positive IC50 values
        df = df[df["standard_value"].astype(float) > 0]

        if df.empty:
            print(f"⚠️ No usable records after filtering for {target_name}")
            continue

        # Add metadata
        df["target_name"] = target_name
        df["target_chembl_id"] = target_id

        bioactivity_list.append(df)
        print(f"✅ Added {len(df)} filtered records for {target_name}")

        time.sleep(0.5)  # avoid API rate limits

    except Exception as e:
        print(f"❌ Error fetching {target_name}: {str(e)}")
        continue
# Out:
# Fetching GTP-binding protein SAR1a (CHEMBL4295960)...
# ⚠️ No IC50 records for GTP-binding protein SAR1a
#
# Fetching Dynamin-like 120 kDa protein, mitochondrial (CHEMBL4105705)...
# ⚠️ No IC50 records for Dynamin-like 120 kDa protein, mitochondrial
#
# Fetching ADP-ribosylation factor GTPase-activating protein 1 (CHEMBL5465332)...
# ⚠️ No IC50 records for ADP-ribosylation factor GTPase-activating protein 1
#
# Fetching Transforming protein p21/H-Ras-1 (CHEMBL2167)...
# ✅ Added 62 filtered records for Transforming protein p21/H-Ras-1
#
# Fetching GTPase NRas (CHEMBL2079845)...
# ✅ Added 1 filtered records for GTPase NRas
#
# Fetching GTPase KRas (CHEMBL2189121)...
# ✅ Added 1052 filtered records for GTPase KRas
#
# Fetching Ras GTPase-activating-like protein IQGAP1 (CHEMBL4295763)...
# ⚠️ No IC50 records for Ras GTPase-activating-like protein IQGAP1
#
# Fetching Rho-GTPase-activating protein 3 (CHEMBL4504)...
# ⚠️ No IC50 records for Rho-GTPase-activating protein 3
#
# Fetching Arf-GAP with SH3 domain, ANK repeat and PH domain-containing protein 1 (CHEMBL2146311)...
# ✅ Added 89 filtered records for Arf-GAP with SH3 domain, ANK repeat and PH domain-containing protein 1
#
# Fetching TBC1 domain family member 15 (CHEMBL4295905)...
# ⚠️ No IC50 records for TBC1 domain family member 15
#
# Fetching Mitofusin-2 (CHEMBL4630807)...
# ⚠️ No IC50 records for Mitofusin-2
#
# Fetching Immunity-related GTPase family M protein (CHEMBL5169093)...
# ⚠️ No IC50 records for Immunity-related GTPase family M protein
#
# Fetching Ribonucleoside-diphosphate reductase M2 chain (CHEMBL1954)...
# ✅ Added 14 filtered records for Ribonucleoside-diphosphate reductase M2 chain
#
# Fetching Carboxy-terminal domain RNA polymerase II polypeptide A small phosphatase 1 (CHEMBL1795098)...
# ✅ Added 1015 filtered records for Carboxy-terminal domain RNA polymerase II polypeptide A small phosphatase 1
#
# Fetching Rac GTPase-activating protein 1 (CHEMBL2146306)...
# ✅ Added 2054 filtered records for Rac GTPase-activating protein 1
#
# Fetching CDC42 small effector protein 1 (CHEMBL3308925)...
# ⚠️ No IC50 records for CDC42 small effector protein 1
#
# Fetching GTP-binding nuclear protein Ran (CHEMBL1741190)...
# ⚠️ No IC50 records for GTP-binding nuclear protein Ran
#
# Fetching 40S ribosomal protein S6 (CHEMBL3351215)...
# ⚠️ No IC50 records for 40S ribosomal protein S6
#
# Fetching Small conductance calcium-activated potassium channel protein 2 (CHEMBL4469)...
# ✅ Added 8 filtered records for Small conductance calcium-activated potassium channel protein 2
#
# Fetching Small conductance calcium-activated potassium channel protein 1 (CHEMBL2369)...
# ✅ Added 8 filtered records for Small conductance calcium-activated potassium channel protein 1
#
# Fetching Small conductance calcium-activated potassium channel protein 3 (CHEMBL3381)...
# ✅ Added 50 filtered records for Small conductance calcium-activated potassium channel protein 3
#
# Fetching Nuclear receptor subfamily 0 group B member 2 (CHEMBL5603)...
# ✅ Added 4 filtered records for Nuclear receptor subfamily 0 group B member 2
#
# Fetching Ras-related C3 botulinum toxin substrate 2 (CHEMBL5581)...
# ⚠️ No IC50 records for Ras-related C3 botulinum toxin substrate 2
#
# Fetching Aurora kinase A-interacting protein (CHEMBL5910)...
# ✅ Added 2 filtered records for Aurora kinase A-interacting protein
#
# Fetching 40S ribosomal protein SA (CHEMBL6119)...
# ⚠️ No IC50 records for 40S ribosomal protein SA
#
# Fetching 40S ribosomal protein S27 (CHEMBL1932893)...
# ✅ Added 18 filtered records for 40S ribosomal protein S27
#
# Fetching Small ubiquitin-related modifier 1 (CHEMBL2146296)...
# ✅ Added 585 filtered records for Small ubiquitin-related modifier 1
#
# Fetching Small ubiquitin-related modifier 2 (CHEMBL2146301)...
# ✅ Added 82 filtered records for Small ubiquitin-related modifier 2
#
# Fetching Eotaxin (CHEMBL3286077)...
# ⚠️ No IC50 records for Eotaxin
#
# Fetching 28S ribosomal protein S29, mitochondrial (CHEMBL4295776)...
# ⚠️ No IC50 records for 28S ribosomal protein S29, mitochondrial
#
# Fetching Small proline-rich protein 3 (CHEMBL4295970)...
# ⚠️ No IC50 records for Small proline-rich protein 3
#
# Fetching 28S ribosomal protein S7, mitochondrial (CHEMBL4295986)...
# ⚠️ No IC50 records for 28S ribosomal protein S7, mitochondrial
#
# Fetching 28S ribosomal protein S23, mitochondrial (CHEMBL4295990)...
# ⚠️ No IC50 records for 28S ribosomal protein S23, mitochondrial
#
# Fetching E3 ubiquitin-protein ligase RNF4 (CHEMBL5291604)...
# ✅ Added 7 filtered records for E3 ubiquitin-protein ligase RNF4
#
# Fetching Oligopeptide transporter small intestine isoform (CHEMBL4605)...
# ✅ Added 143 filtered records for Oligopeptide transporter small intestine isoform
#
# Fetching L-type amino acid transporter 2 (CHEMBL4301)...
# ⚠️ No IC50 records for L-type amino acid transporter 2
#
# Fetching Solute carrier family 2, facilitated glucose transporter member 5 (CHEMBL5875)...
# ⚠️ No IC50 records for Solute carrier family 2, facilitated glucose transporter member 5
#
# Fetching IGF-like family receptor 1 (CHEMBL2029192)...
# ✅ Added 1 filtered records for IGF-like family receptor 1
#
# Fetching Alpha-ketoglutarate-dependent dioxygenase FTO (CHEMBL2331065)...
# ✅ Added 391 filtered records for Alpha-ketoglutarate-dependent dioxygenase FTO
#
# Fetching C-C motif chemokine 7 (CHEMBL3217391)...
# ⚠️ No IC50 records for C-C motif chemokine 7
#
# Fetching U5 small nuclear ribonucleoprotein 200 kDa helicase (CHEMBL4105972)...
# ✅ Added 55 filtered records for U5 small nuclear ribonucleoprotein 200 kDa helicase
#
# Fetching C-C motif chemokine 17 (CHEMBL4295915)...
# ⚠️ No IC50 records for C-C motif chemokine 17
#
# Fetching Ubiquitin-40S ribosomal protein S27a (CHEMBL4523597)...
# ⚠️ No IC50 records for Ubiquitin-40S ribosomal protein S27a
#
# Fetching Fractalkine (CHEMBL4630883)...
# ⚠️ No IC50 records for Fractalkine
#
# Fetching Carboxypeptidase N, catalytic subunit (CHEMBL4713)...
# ✅ Added 32 filtered records for Carboxypeptidase N, catalytic subunit
#
# Fetching L-type amino acid transporter 1 (CHEMBL4459)...
# ✅ Added 81 filtered records for L-type amino acid transporter 1
#
# Fetching L-type amino acid transporter 3 (CHEMBL4148)...
# ✅ Added 3 filtered records for L-type amino acid transporter 3
#
# Fetching Aldo-keto reductase family 1 member B10 (CHEMBL5983)...
# ✅ Added 164 filtered records for Aldo-keto reductase family 1 member B10
#
# Fetching C-C motif chemokine 5 (CHEMBL1275217)...
# ✅ Added 34 filtered records for C-C motif chemokine 5
#
# Fetching C-C motif chemokine 2 (CHEMBL1649052)...
# ✅ Added 73 filtered records for C-C motif chemokine 2
#
# Fetching Histone-lysine N-methyltransferase ASH1L (CHEMBL3588739)...
# ✅ Added 378 filtered records for Histone-lysine N-methyltransferase ASH1L
#
# Fetching Testis-specific serine/threonine-protein kinase 6 (CHEMBL3627582)...
# ✅ Added 3 filtered records for Testis-specific serine/threonine-protein kinase 6
#
# Fetching C-X-C motif chemokine 10 (CHEMBL3712964)...
# ⚠️ No IC50 records for C-X-C motif chemokine 10
#
# Fetching ADP-ribosylation factor-like protein 8B (CHEMBL4295962)...
# ⚠️ No IC50 records for ADP-ribosylation factor-like protein 8B
#
# Fetching CDGSH iron-sulfur domain-containing protein 2 (CHEMBL4523399)...
# ✅ Added 3 filtered records for CDGSH iron-sulfur domain-containing protein 2
#
# Fetching RNA N6-adenosine-methyltransferase METTL16 (CHEMBL5465326)...
# ⚠️ No IC50 records for RNA N6-adenosine-methyltransferase METTL16
#
# Fetching Caspase-3 (CHEMBL2334)...
# ✅ Added 2430 filtered records for Caspase-3
#
# Fetching Caspase-2 (CHEMBL4884)...
# ✅ Added 73 filtered records for Caspase-2
#
# Fetching Caspase-8 (CHEMBL3776)...
# ✅ Added 442 filtered records for Caspase-8
#
# Fetching Caspase-4 (CHEMBL2226)...
# ✅ Added 28 filtered records for Caspase-4
#
# Fetching Caspase-5 (CHEMBL3131)...
# ✅ Added 56 filtered records for Caspase-5
#
# Fetching Caspase-1 (CHEMBL4801)...
# ✅ Added 711 filtered records for Caspase-1
#
# Fetching Caspase-6 (CHEMBL3308)...
# ✅ Added 276 filtered records for Caspase-6
#
# Fetching Caspase-9 (CHEMBL2273)...
# ✅ Added 48 filtered records for Caspase-9
#
# Fetching Caspase-7 (CHEMBL3468)...
# ✅ Added 566 filtered records for Caspase-7
#
# Fetching Caspase-10 (CHEMBL5037)...
# ✅ Added 11 filtered records for Caspase-10
#
# Fetching Caspase-14 (CHEMBL5991)...
# ✅ Added 6 filtered records for Caspase-14
#
# Fetching C-C motif chemokine 22 (CHEMBL4295649)...
# ⚠️ No IC50 records for C-C motif chemokine 22
#
# Fetching Aminoacyl tRNA synthase complex-interacting multifunctional protein 1 (CHEMBL4295810)...
# ⚠️ No IC50 records for Aminoacyl tRNA synthase complex-interacting multifunctional protein 1

# %%
if bioactivity_list:
    specified_df = pd.concat(bioactivity_list, ignore_index=True)
    print(f"\n🎯 Total records collected after strict filtering: {specified_df.shape[0]}")

    # Save to CSV
    specified_df.to_csv("RAW_Specified_Small_GTPases_Bioactivity_Filtered.csv", index=False)
    print("💾 Saved as RAW_Specified_Small_GTPases_Bioactivity_Filtered.csv")

    # Preview
    print(specified_df[[
        "molecule_chembl_id", "canonical_smiles",
        "standard_value", "standard_units",
        "target_name", "target_chembl_id"
    ]].head())
else:
    print("\n❌ No data collected after applying filters")
# Out:
# /tmp/ipython-input-2953462270.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   specified_df = pd.concat(bioactivity_list, ignore_index=True)
# 🎯 Total records collected after strict filtering: 11059
# 💾 Saved as RAW_Specified_Small_GTPases_Bioactivity_Filtered.csv
#   molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL11252  Cn1cc(NC(=O)c2cc(NC(=O)c3cc(NC=O)cn3C)cn2C)cc1...
# 1       CHEMBL552863  Cl.Cn1cc(NC(=O)c2cc(NC(=O)c3cc(NC(=O)c4cc5cc(N...
# 2       CHEMBL554247  Cl.Cn1cc(NC(=O)c2cc(NC(=O)c3cc(NC(=O)c4cc5cc(N...
# 3       CHEMBL536328  Cl.Cn1cc(NC(=O)c2cc(NC(=O)c3cc(NC(=O)c4cc5cc(N...
# 4       CHEMBL552690  Cl.Cn1cc(NC(=O)c2cc(NC(=O)c3cc(NC(=O)c4nc5cc(N...
#
#   standard_value standard_units                       target_name  \
# 0          200.0             nM  Transforming protein p21/H-Ras-1
# 1           20.0             nM  Transforming protein p21/H-Ras-1
# 2           15.0             nM  Transforming protein p21/H-Ras-1
# 3           20.0             nM  Transforming protein p21/H-Ras-1
# 4           15.0             nM  Transforming protein p21/H-Ras-1
#
#   target_chembl_id
# 0       CHEMBL2167
# 1       CHEMBL2167
# 2       CHEMBL2167
# 3       CHEMBL2167
# 4       CHEMBL2167
